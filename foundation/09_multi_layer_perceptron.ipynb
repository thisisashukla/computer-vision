# %% [markdown]
# # Multi Layered Perceptron

# %% [markdown]
# ## Introduction
#
# Multi Layered Perceptron (MLP) is a more complex network as compared to the single layer version. It can have multiple layers between the input and the output layer. These layers are called the **hidden layers**.
# It can handle the cases where a SLP fails.

# %%
from IPython.display import Image
from IPython.core.display import HTML

# %%
Image(url= "https://www.oreilly.com/library/view/getting-started-with/9781786468574/graphics/B05474_04_05.jpg")
# Out:
# <img src="https://www.oreilly.com/library/view/getting-started-with/9781786468574/graphics/B05474_04_05.jpg"/>

# %% [markdown]
# #### Running Util Notebooks

# %%
import sys
sys.path.append('../')
from basics import Data_Utils
from basics import Plot_Utils
# Out:
# Plot Utilities Imported !
# Data Utilities Imported !

# %% [markdown]
# #### Importing Required Libraries

# %%
import math
import keras
import numpy as np
import pandas as pd
from keras.layers import Dense
import matplotlib.pyplot as plt
from keras.models import Sequential
from sklearn.datasets import make_moons
from sklearn.model_selection import train_test_split
np.random.seed(5)
# Out:
# Using TensorFlow backend.

# %% [markdown]
# #### Generating, Labelling & Visualizing the Data

# %%
data = get_spiral(4, 0.005)
label_ohe = []
for i in range(np.shape(data)[0]):
    if(i > np.shape(data)[0]/2):
        label_ohe.append([0, 1])
    else:
        label_ohe.append([1, 0])

label_ohe = np.array(label_ohe)
print('Shapes ', np.shape(data), np.shape(label_ohe))
get_plot(data, label_ohe, title = 'Scatter plot dataset')
# Out:
# Shapes  (801, 2) (801, 2)

# %% [markdown]
# #### Preparing The MLP Model

# %%
# Splitting Data into Train and Test
x_train, x_test, y_train, y_test = train_test_split(data, label_ohe, test_size=0.33, random_state=42)

# %%
# Plotting train and test data
get_plot(x_train, y_train, title = 'Scatter plot for training dataset')
get_plot(x_test, y_test, title = 'Scatter plot for testing dataset')

# %% [markdown]
# #### Defining Model Settings

# %%
# create model
model = Sequential()
model.add(Dense(5, input_dim=2, activation='sigmoid'))
model.add(Dense(2, activation='sigmoid'))

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
history = model.fit(x_train, y_train, epochs=150, batch_size=1)
# Out:
# Epoch 1/150
# 536/536 [==============================] - 1s 3ms/step - loss: 0.3103 - acc: 0.9646
# Epoch 2/150
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3033 - acc: 0.9646
# Epoch 3/150
# 536/536 [==============================] - 1s 1ms/step - loss: 0.2965 - acc: 0.9608
# Epoch 4/150
# 536/536 [==============================] - 1s 1ms/step - loss: 0.2897 - acc: 0.9636
# Epoch 5/150
# 536/536 [==============================] - 1s 1ms/step - loss: 0.2840 - acc: 0.9608
# Epoch 6/150
# 536/536 [==============================] - 1s 1ms/step - loss: 0.2780 - acc: 0.9655
# Epoch 7/150
# 536/536 [==============================] - 1s 1ms/step - loss: 0.2727 - acc: 0.9664
# Epoch 8/150
# 536/536 [==============================] - 1s 1ms/step - loss: 0.2670 - acc: 0.9608
# Epoch 9/150
# 536/536 [==============================] - 1s 1ms/step - loss: 0.2617 - acc: 0.9664
# Epoch 10/150
# ...

# %%
plt.plot(history.history['loss'])
plt.xlabel('Batch #')
plt.ylabel('Loss [entropy]')
plt.title('Variation of network loss through the epochs')
plt.show()

# %%
pred = [[0, 1] if e[0]<e[1] else [1, 0] for e in model.predict((x_test))]

# %%
get_plot(x_test, pred, title = 'Test data with predicted classes from the network')

# %%
get_plot(x_test, y_test, title = 'Test data with actual classes from the network')

# %% [markdown]
# ## Exercise

# %% [markdown]
# Train a multi layer percetron network so that the trained network mimics an XOR logical gate. Generate the dataset accordingly and report the weights of your network. The output of the cell below shows the truth table for the XOR gate.

# %%
import pandas as pd
df = pd.DataFrame({'A': [0, 0, 1, 1], 'B': [0, 1, 0, 1], 'XOR': [0, 1, 1, 0]})
df
# Out:
#    A  B  XOR
# 0  0  0    0
# 1  0  1    1
# 2  1  0    1
# 3  1  1    0

# %%
# Write your code here
