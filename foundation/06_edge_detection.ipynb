# %% [markdown]
# # Edge Detection

# %%
# Importing libraries
import cv2
import sys
import imutils
import numpy as np
sys.path.append('../')
import matplotlib.pyplot as plt
from basics import functions as fn
import matplotlib.gridspec as gridspec
np.set_printoptions(threshold=sys.maxsize, linewidth = 120)

# %%
# Reading a sample image
img = cv2.imread('C://Users//ankushukla//Documents//Work//CV Training//Images//taj.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(img, cmap='gray', vmin=0, vmax=255)
plt.title('Taj Image')
plt.show()

# %%
sobelx = np.array([[1,2,1], [0,0,0],[-1,-2,-1]])
sobely = np.array([[-1,0,1], [-2,0,2],[-1,0,1]])
laplacian = np.array([[0,-1,0], [-1,4,-1],[0,-1,0]])
print(sobelx)
print(sobely)
print(laplacian)
gradientx = cv2.filter2D(img, -1, sobelx)
gradienty = cv2.filter2D(img, -1, sobely)
lapImg = cv2.filter2D(img, -1, laplacian)

f, (ax1, ax2, ax3, ax4) = plt.subplots(1,4, figsize = (50,50))
ax1.imshow(img, cmap='gray', vmin=0, vmax=255)
ax2.imshow(gradientx, cmap='gray', vmin=0, vmax=255)
ax3.imshow(gradienty, cmap='gray', vmin=0, vmax=255)
ax4.imshow(lapImg, cmap='gray', vmin=0, vmax=255)
plt.show()
# Out:
# [[ 1  2  1]
#  [ 0  0  0]
#  [-1 -2 -1]]
# [[-1  0  1]
#  [-2  0  2]
#  [-1  0  1]]
# [[ 0 -1  0]
#  [-1  4 -1]
#  [ 0 -1  0]]

# %%
img = cv2.GaussianBlur(img, (3,3), 0)
# ret, img = cv2.threshold(img, 127, 255, cv2.THRESH_BINARY)
# img = cv2.adaptiveThreshold(img, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY, 115, 1)
# imge = cv2.erode(img, kernel = np.ones((3, 3),np.uint8), iterations = 3)

# %%
sobelx = np.array([[1,2,1], [0,0,0],[-1,-2,-1]])
sobely = np.array([[-1,0,1], [-2,0,2],[-1,0,1]])
laplacian = np.array([[0,-1,0], [-1,4,-1],[0,-1,0]])
print(sobelx)
print(sobely)
print(laplacian)
gradientx = cv2.filter2D(img, -1, sobelx)
gradienty = cv2.filter2D(img, -1, sobely)
lapImg = cv2.filter2D(img, -1, laplacian)

f, (ax1, ax2, ax3, ax4) = plt.subplots(1,4, figsize = (50,50))
ax1.imshow(img, cmap='gray', vmin=0, vmax=255)
ax2.imshow(gradientx, cmap='gray', vmin=0, vmax=255)
ax3.imshow(gradienty, cmap='gray', vmin=0, vmax=255)
ax4.imshow(lapImg, cmap='gray', vmin=0, vmax=255)
plt.show()
# Out:
# [[ 1  2  1]
#  [ 0  0  0]
#  [-1 -2 -1]]
# [[-1  0  1]
#  [-2  0  2]
#  [-1  0  1]]
# [[ 0 -1  0]
#  [-1  4 -1]
#  [ 0 -1  0]]

# %% [markdown]
# ## Simple Edge Activity

# %%
e1 = cv2.imread('C://Users//ankushukla//Documents//Work//CV Training//Images//edge1.png')
e1 = cv2.cvtColor(e1, cv2.COLOR_BGR2RGB)
e2 = cv2.imread('C://Users//ankushukla//Documents//Work//CV Training//Images//edge2.png')
e2 = cv2.cvtColor(e2, cv2.COLOR_BGR2RGB)
e3 = cv2.imread('C://Users//ankushukla//Documents//Work//CV Training//Images//edge3.png')
e3 = cv2.cvtColor(e3, cv2.COLOR_BGR2RGB)
e4 = cv2.imread('C://Users//ankushukla//Documents//Work//CV Training//Images//edge4.png')
e4 = cv2.cvtColor(e4, cv2.COLOR_BGR2RGB)
f, (ax1, ax2,ax3,ax4) = plt.subplots(1,4, figsize = (40,10))
ax1.imshow(e1)
ax2.imshow(e2)
ax3.imshow(e3)
ax4.imshow(e4)
plt.show()

# %%
e1 = e1[:,:,2]
e2 = e2[:,:,2]
e3 = e3[:,:,2]
e4 = e4[:,:,2]
f, (ax1, ax2,ax3,ax4) = plt.subplots(1,4, figsize = (40,10))
ax1.imshow(e1, cmap='gray', vmin=0, vmax=255)
ax2.imshow(e2, cmap='gray', vmin=0, vmax=255)
ax3.imshow(e3, cmap='gray', vmin=0, vmax=255)
ax4.imshow(e4, cmap='gray', vmin=0, vmax=255)
plt.show()

# %%
sobelx = np.array([[-1,-2,-1], [0,0,0],[1,2,1]])
x1 = cv2.filter2D(e1, -1, sobelx)
x2 = cv2.filter2D(e2, -1, sobelx)
x3 = cv2.filter2D(e3, -1, sobelx)
x4 = cv2.filter2D(e4, -1, sobelx)
f, (ax1, ax2,ax3,ax4) = plt.subplots(1,4, figsize = (40,10))
ax1.imshow(x1, cmap='gray', vmin=0, vmax=255)
ax2.imshow(x2, cmap='gray', vmin=0, vmax=255)
ax3.imshow(x3, cmap='gray', vmin=0, vmax=255)
ax4.imshow(x4, cmap='gray', vmin=0, vmax=255)
plt.show()

# %%
print('%tage of glass filled in 1st image {}'.format(100*(x1.shape[0]-np.argmax(x1[:,0]))/x1.shape[0]))
print('%tage of glass filled in 2nd image {}'.format(100*(x2.shape[0]-np.argmax(x2[:,0]))/x2.shape[0]))
print('%tage of glass filled in 3rd image {}'.format(100*(x3.shape[0]-np.argmax(x3[:,0]))/x3.shape[0]))
print('%tage of glass filled in 4th image {}'.format(100*(x4.shape[0]-np.argmax(x4[:,0]))/x4.shape[0]))
# Out:
# %tage of glass filled in 1st image 33.663366336633665
# %tage of glass filled in 2nd image 48.01980198019802
# %tage of glass filled in 3rd image 58.91089108910891
# %tage of glass filled in 4th image 83.16831683168317

# %%
# Reading a sample image
img = cv2.imread('C://Users//ankushukla//Documents//Work//CV Training//Images//edge.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
f, (ax1, ax2) = plt.subplots(1,2, figsize = (10,5))
ax1.imshow(img, cmap='gray', vmin=0, vmax=255)
ax1.set_title('Sudoku Image')
ax2.plot(cv2.calcHist([img],[0],None,[256],[0,256]), color = 'blue')
ax1.set_title('Sudoku Image Histogram')
plt.show()

# %%
# img = cv2.GaussianBlur(img, (3,3), 0)
gradientx = cv2.Sobel(img,cv2.CV_64F,0,1,ksize=5)
gradienty = cv2.Sobel(img,cv2.CV_64F,1,0,ksize=5)

f, (ax1, ax2, ax3) = plt.subplots(1,3, figsize = (50,50))
ax1.imshow(img, cmap='gray', vmin=0, vmax=255)
ax2.imshow(gradientx, cmap='gray', vmin=0, vmax=255)
ax3.imshow(gradienty, cmap='gray', vmin=0, vmax=255)
plt.show()

# %%
canny = cv2.Canny(img,5,100)
plt.imshow(canny, cmap='gray', vmin=0, vmax=255)
# Ref : https://docs.opencv.org/3.1.0/da/d22/tutorial_py_canny.html
