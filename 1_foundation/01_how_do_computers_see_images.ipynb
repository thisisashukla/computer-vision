# %% [markdown]
# # How Do Computers See Images
#
# Humans are very much capable of seeing, interpreting and understanding this beautyful visual world around us. However it has been a tricky task for us humans to make computers do the same.
#
# One of the differentiating factor between humans and computers is that computers work and understand the world in digitally. This mandates that images be converted to digital form for the computers to even store and see them.

# %% [markdown]
# ## Converting Light to A Digital Image
#
# There is a process of capturing the light present around us and convert it to a format suitable for computers to understand. The image below shows a high level view of this process.
#
# <figure>
#     <img src="../assets/images/process.jpg" width = 1000px/>
#     <figcaption style = "text-align:center">High Level Overview of Image Digitization Process
#     </figcaption>
# </figure>

# %% [markdown]
# ## Reading/Importing Images
#
# The process shown above enables us to create digital images and store them on our computers. To visualize or see these images, some steps are reverted.
#
# <br/>
#
# <figure>
#     <img src="../assets/images/read_image.jpg" width = 700px/>
#     <figcaption style = "text-align:center">Reading Images
#     </figcaption>
# </figure>

# %% [markdown]
# This reading operation is done by image viewer applications on your computers as well can also be done using differnt programming languages.
#
# For this course we will be looking at how we can read, manipulate and make a machine understand images using Python as out tool for programming.
#
# **So Let's Dive In and Import an Image Using Python. Write Some _CODE_.**

# %% [markdown]
# ## Importing Images In Python
#
# Let's see how we can import and visualize image using different Python packages.

# %%
# Importing libraries

import sys
import cv2
import numpy as np
from PIL import Image
from skimage import io
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
np.set_printoptions(threshold=sys.maxsize, linewidth = 120)

# %%
# Reading an image in Python using OpenCV

image = cv2.imread('..//assets//images//rupee.jpg')
image_ = cv2.resize(image, (20, 30))
image_[:, :, 0]
# Out:
# array([[255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255],
#        [255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255],
#        [255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255],
#        [255, 255, 255, 255, 255, 255, 255,   0,   0,   0,   0,   0,   0,   0, 255, 255, 255, 255, 255, 255],
#        [255, 255, 255, 255, 255, 255, 255,   0,   0,   0,   0,   0,   0,   0, 255, 255, 255, 255, 255, 255],
#        [255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255,   0, 255, 255, 255, 255, 255, 255, 255, 255],
#        [255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255,   0, 255, 255, 255, 255, 255, 255, 255, 255],
#        [255, 255, 255, 255, 255, 255, 255, 255, 255, 255, 255,   0, 255, 255, 255, 255, 255, 255, 255, 255],
#        [255, 255, 255, 255, 255, 255, 255,   0,   0,   0,   0,   0,   0,   0, 255, 255, 255, 255, 255, 255],
# ...

# %%
# Visualizing the Image using Matplotlib. Image Ref: https://www.vecteezy.com/vector-art/658591-indian-rupee-sign

plt.imshow(image_)
plt.title('Indian Rupee Symbol')
plt.axis('off')
plt.show()

# %%
# Reading a sample image

path = '..//assets//images//gurgaon-1.jpg'

im_cv2 = cv2.imread(path)
im_pil = Image.open(path)
im_skimage = io.imread(path)
im_plt = plt.imread(path)

# %%
# Displaying the images

f, ax = plt.subplots(2, 2, figsize = (10, 10))
ax[0][0].imshow(im_cv2)
ax[0][1].imshow(im_pil)
ax[1][0].imshow(im_skimage)
ax[1][1].imshow(im_plt)

for x, lib in zip([ax[0][0], ax[0][1], ax[1][0], ax[1][1]], ['OpenCV', 'Pillow', 'Scikit-Image', 'Matplotlib']):
    x.set_title(lib)
    x.axis('off')
    
plt.suptitle('Reading Image in Python Using Different Utitlities')
plt.show()

# %% [markdown]
# ### Recommended Reading
#
# [10 Python image manipulation tools.](https://towardsdatascience.com/image-manipulation-tools-for-python-6eb0908ed61f)

# %%
# By default OpenCV reads the image as BGR which needs to be converted to RGB. Let's do that.

im_cv2_ = cv2.cvtColor(im_cv2, cv2.COLOR_BGR2RGB)
plt.imshow(im_cv2_)
plt.title('OpenCV Image in RGB')
plt.axis('off')
plt.show()

# %% [markdown]
# ## How Are Colored Images Stored
#
# Colored images are stored as 3 dimensional matrix.
