# %% [markdown]
# # Contextual Image Segmentation Techniques
#
# Let's look at applying clustering on image for segmentation. Let's look at segmenting color images for this case.

# %%
# importing libraries

import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from matplotlib import animation, rc
from ipywidgets import interact, widgets
import matplotlib.animation as animation
from IPython.display import HTML, display
# %matplotlib inline

# %%
# reading image using opencv

image = cv2.imread('..//images//lonavala-1.jpg')
print('Image matrix shape {}'.format(image.shape))
# Out:
# Image matrix shape (1365, 2048, 3)

# %%
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
image_g = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
print('Image matrix shape {}'.format(image_g.shape))
# Out:
# Image matrix shape (1365, 2048)

# %%
f, ax = plt.subplots(1, 2, figsize = (15, 10))
ax[0].imshow(image)
ax[1].imshow(image_g, cmap = 'gray')
plt.show()

# %%
image_data = image.reshape(image.shape[0]*image.shape[1], image.shape[2])
imdf = pd.DataFrame(data = image_data, columns = ['r', 'g', 'b'])

# %%
imdf.head()
# Out:
#      r    g    b
# 0  201  210  239
# 1  204  211  239
# 2  199  211  235
# 3  193  214  233
# 4  193  216  234

# %%
kmeans = KMeans(10)
kmeans.fit(imdf)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=10, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
imdf.loc[:, 'cluster'] = kmeans.labels_

# %%
imdf['cluster'].value_counts()
# Out:
# 0    749519
# 2    362017
# 6    349239
# 1    289211
# 8    227023
# 7    217973
# 3    182694
# 9    175933
# 4    122240
# 5    119671
# Name: cluster, dtype: int64

# %%
kmeans.cluster_centers_
# Out:
# array([[220.44949122, 224.89291341, 233.3004871 ],
#        [106.95352999,  99.94517576,  75.75929918],
#        [ 47.69381974,  53.94243798,  49.69108934],
#        [116.97777997, 151.38540076, 159.96723079],
#        [216.00415185, 194.51635814, 176.45990765],
#        [195.39884692, 162.46120664, 113.44263389],
#        [ 77.78404306,  76.04853119,  60.62494662],
#        [ 26.40283204,  33.04833892,  29.86520417],
#        [159.15413656, 182.55144053, 194.30200441],
#        [146.10385659, 126.92466197,  88.91367233]])

# %%
clustermeans = pd.DataFrame(data = kmeans.cluster_centers_, columns = ['rc', 'gc', 'bc'])
clustermeans.loc[:, 'cluster'] = clustermeans.index

# %%
imdf = imdf.merge(clustermeans, on = 'cluster', how = 'left')

# %%
image_cl = imdf[['rc', 'gc', 'bc']].values.reshape(image.shape[0], image.shape[1], image.shape[2])

# %%
f, ax = plt.subplots(1, 2, figsize = (15, 10))
ax[0].imshow(image)
ax[1].imshow(image_cl/255, cmap = 'gray')
plt.show()

# %%
image_cl.min()
# Out:
# 26.40283204258725
